# %% [markdown]
# <a href="https://colab.research.google.com/github/brunogtds/datavisualization_Python/blob/main/proportion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **sobre proporção**

# %%
#gráficos de barras são boas opções
#atribui-se a William Playfair a criação de gráficos de barra (1786)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %matplotlib inline

# %%
energy_type = ['Nuclear', 'Hydro', 'Gas', 'Oil', 'Coal', 'Biofuel']
energy = [5, 6, 15, 29, 24, 8]

energy_type[1]
# Out:
# 'Hydro'

# %%
plt.bar(energy_type, energy, color='lightgreen')
plt.xlabel('Energy source')
plt.ylabel('Energy output (GJ)')
plt.title('Energy output from various sources', fontsize=14, weight='bold')

plt.show()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Rogerio-mack/Visualizacao-de-Dados-em-Python/main/data/energy_types.csv')

# %%
df.head()
# Out:
#   country country_name                  type    level     2016     2017  \
# 0      BE      Belgium  Conventional thermal  Level 1  30728.0  31316.0
# 1      BE      Belgium               Nuclear  Level 1  41430.0  40128.5
# 2      BE      Belgium                 Hydro  Level 1   1476.0   1360.9
# 3      BE      Belgium    Pumped hydro power  Level 2   1110.0   1093.2
# 4      BE      Belgium                  Wind  Level 1   5340.0   6387.9
#
#         2018
# 0  30092.635
# 1  26995.628
# 2   1239.248
# 3    983.190
# 4   7177.346

# %%
df.describe()
# Out:
#                 2016           2017           2018
# count     296.000000     296.000000     296.000000
# mean    12783.361422   12910.957946   12796.198074
# std     41066.361831   41029.499878   39423.360898
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%       373.282000     351.894000     278.354000
# 75%      5677.250000    5924.456750    6790.148750
# max    390141.000000  379093.955000  393153.254000

# %%
df.dropna(inplace=True)

# %%
df.sort_values(['country_name','type'],inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
be = df[df.country_name == 'Belgium']
pt = df[df.country_name == 'Portugal']

# %%
df.head()
# Out:
#   country country_name                  type    level    2016      2017  \
# 0      AL      Albania  Conventional thermal  Level 1     0.0     0.000
# 1      AL      Albania            Geothermal  Level 1     0.0     0.000
# 2      AL      Albania                 Hydro  Level 1  7136.0  4496.607
# 3      AL      Albania               Nuclear  Level 1     0.0     0.000
# 4      AL      Albania                 Other  Level 1     0.0     0.000
#
#        2018
# 0     0.000
# 1     0.000
# 2  8596.537
# 3     0.000
# 4     0.000

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.bar(be['type'], be['2018'], color='lightblue')
plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Belgium - energy by type (2018)', fontsize=14, weight='bold')

plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')

plt.subplot(1,2,2)
plt.barh(pt['type'],pt['2018'],color='lightgreen')
plt.ylabel('Energy type')
plt.xlabel('Energy (giga watts)')
plt.title('Portugal - energy by type (2018)', fontsize=14, weight='bold')

plt.xticks(fontsize='small')
plt.yticks(fontsize='small')

plt.tight_layout()
plt.show()

# %%
#adicionar anotações em gráficos de barro (não disponível no matplotlib)

def autolabel(rects, ax, s=10, w='normal', c='k'):
  for rect in rects:
    height = rect.get_height()
    ax.annotate('{:.0f}'.format(height), xy=(rect.get_x() + rect.get_width()/2, height), xytext=(0,3), textcoords='offset points', ha='center', va='bottom', fontsize=s, weight=w, color=c)

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.bar(be['type'], be['2018'], color='lightblue')
plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Belgium - energy by type (2018)', fontsize=14, weight='bold')
plt.ylim([0,450000])
plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')

plt.subplot(1,2,2)
rects1 = plt.bar(be['type'], be['2018'], color='lightblue')
autolabel(rects1, plt, 10, w='bold')

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Belgium - energy by type (2018)', fontsize=14, weight='bold')
plt.ylim([0,450000])
plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.bar(be['type'], be['2018'], color='yellow', label='BE')
plt.bar(pt['type'], pt['2018'], color='red', label='PT')

plt.ylabel('Energy type')
plt.xlabel('Energy (Giga watts)')
plt.title('Belgium & Portugual - Energy by type in 2018', fontsize=14, weight='bold')
plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')
plt.legend()

plt.subplot(1,2,2)
plt.bar(be['type'], be['2018'], color='yellow', label='BE', alpha=0.5, edgecolor='k')
plt.bar(pt['type'], pt['2018'], color='red', label='PT', alpha=0.5, edgecolor='k')

plt.ylabel('Energy type')
plt.xlabel('Energy (Giga watts)')
plt.title('Belgium & Portugal - Energy by type in 2018', fontsize=14, weight='bold')
plt.xticks(rotation=60, fontsize='small')

plt.yticks(fontsize='small')
plt.legend()

plt.tight_layout()
plt.show()

# %%
f, ax= plt.subplots(1,2, sharey=True, figsize=(12,6))

ax[0].bar(pt['type'], pt['2018'], color='red', label='PT', alpha=0.5, edgecolor='k')
ax[0].bar(be['type'], be['2018'], color='yellow', label='BE', alpha=0.5, edgecolor='k')

ax[0].set_xlabel('Energy type')
ax[0].set_ylabel('Energy (giga watts)')
ax[0].set_title('Belgium & Portugal - Energy by type(2018)', fontsize=14, weight='bold')
ax[0].set_ylim([0,80000])

ax[0].tick_params(axis='x', rotation=60, size=10)
ax[0].tick_params(axis='y', size=10)
ax[0].legend()

ax[0].text(3.5, be[be['type'] == 'Hydro']['2018'].values[0], '{:.0f}'.format(be[be['type'] == 'Hydro']['2018'].values[0]), color='grey', fontsize=12)
ax[0].text(3.5, pt[pt['type'] == 'Hydro']['2018'].values[0], '{:.0f}'.format(pt[pt['type'] == 'Hydro']['2018'].values[0]), color='r', weight='bold', fontsize=12)

ax[1].bar(be['type'], be['2018'], color='yellow', label='BE', alpha=0.5, edgecolor='k')
ax[1].bar(pt['type'], pt['2018'], bottom=pt['2018'], color='red', label='PT', alpha=0.5, edgecolor='k')
ax[1].set_xlabel('Energy type')
ax[1].set_ylabel('Energy (giga watts)')
ax[1].set_title('Belgium & Portugal - Energy by type (2018)', fontsize=14, weight='bold')

ax[1].text(3.5, be[be['type'] == 'Hydro']['2018'].values[0], '{:.0f}'.format(be[be['type'] == 'Hydro']['2018'].values[0]), color='grey', fontsize=12)
ax[1].text(3.5, pt[pt['type'] == 'Hydro']['2018'].values[0], '{:.0f}'.format(pt[pt['type'] == 'Hydro']['2018'].values[0]), color='r', weight='bold', fontsize=12)

ax[1].tick_params(axis='x', rotation=60)
ax[1].legend()

plt.tight_layout()
plt.show()

# %%
top5 = df.groupby('country_name')['2018'].sum().nlargest(5).keys()
import matplotlib.cm as cm
cmap = cm.coolwarm_r (np.linspace(0, 1, len(top5)))

# %%
plt.figure(figsize=(8,6))
bottom= df[df.country_name == top5[0]]['2018'].values*0

for k, country in enumerate(top5):
  plt.bar(df[df.country_name == country]['type'], df[df.country_name == country]['2018'], alpha=0.85, bottom=bottom, label=country, color=cmap[k])
  bottom = bottom + df[df.country_name == country]['2018'].values

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Top 5 - energy by type (2018)', fontsize=14, weight='bold')
plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')
plt.legend()

plt.show()

# %%
dftop5 = df[df.country_name.isin(top5)]
dftop5sum= pd.DataFrame(dftop5.groupby(['type'])['2018'].sum()).reset_index()
dftop5sum= dftop5sum.rename(columns={'2018':'sum'})
dftop5 = pd.merge(dftop5, dftop5sum, on='type')
dftop5['proporcao'] = dftop5['2018'] / dftop5['sum']

dftop5.head()
# Out:
#   country country_name                  type    level        2016        2017  \
# 0      FR       France  Conventional thermal  Level 1   60607.854   68922.949
# 1      DE      Germany  Conventional thermal  Level 1  390141.000  376128.000
# 2      IT        Italy  Conventional thermal  Level 1  190121.000  199722.444
# 3      ES        Spain  Conventional thermal  Level 1  108210.000  126885.000
# 4      TR       Turkey  Conventional thermal  Level 1  174166.000  199910.043
#
#          2018         sum  proporcao
# 0   53956.440  864677.925   0.062401
# 1  320437.701  864677.925   0.370586
# 2  185046.000  864677.925   0.214006
# 3  110084.238  864677.925   0.127312
# 4  195153.546  864677.925   0.225695

# %%
import matplotlib.cm as cm
cmap = cm.coolwarm_r (np.linspace(0, 1, len(top5)))

plt.figure(figsize=(8,6))

bottom= df[df.country_name == top5[0]]['2018'].values*0
for k, country in enumerate(top5):
  plt.bar(dftop5[dftop5.country_name == country]['type'], dftop5[dftop5.country_name == country]['proporcao'] * 100, alpha=0.85, bottom=bottom, label=country, color=cmap[k])
  bottom= bottom + dftop5[dftop5.country_name == country]['proporcao'].values * 100

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Top 5 - Energy byb type (2018)', fontsize=14, weight='bold')

plt.ylim([0,110])
plt.xticks(rotation=60, fontsize='small')
plt.yticks(fontsize='small')
plt.legend()

plt.show()

# %%
#barras paralelas

plt.figure(figsize=(8,6))
ind= np.arange(len(be['type']))
barwidth=0.45

plt.bar(ind, be['2018'], barwidth, label='BE', color='yellow')
plt.bar(ind + barwidth, pt['2018'], barwidth, label='PT', color='red')

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Belgium & Portugal - energy by type (2018)', fontsize=14, weight='bold')
plt.xticks(ind + barwidth / 2, dftop5['type'].unique(), rotation=60)
plt.legend()

plt.show()

# %%
import matplotlib.cm as cm
cmap = cm.viridis(np.linspace(0,1,len(top5)))

plt.figure(figsize=(12,6))
ind= np.arange(len(be['type']))
barwidth=0.16

for k, country in enumerate(top5):
  plt.bar(ind + barwidth*k, dftop5[dftop5.country_name == country]['2018'], barwidth, label=country, color=cmap[k])

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Top 5 - Energy by type (2018)', fontsize=14, weight='bold')
plt.xticks(ind + barwidth/2, dftop5['type'].unique(), rotation=60)
plt.legend()

plt.text(ind[0]+0.3, max(dftop5['2018'])/1.8, 'Top 5 - Ainda predominam \nas fontes térmicas', fontsize=12, color='grey')
plt.text(ind[3]+0.4, max(dftop5['2018'])/1.2, 'Top 5 - França lidera \nenergia nuclear', fontsize=12, color='grey')
plt.text(ind[5]+0.9, max(dftop5['2018'])/2.8, 'Top 5 - Alemanha lidera \nergia eólica e solar', fontsize=12, color='grey')

plt.show()

# %%
cars = sns.load_dataset('mpg')
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg_mean_usa = cars[cars.origin == 'usa'].groupby('model_year')['mpg'].mean()
mpg_mean_japan = cars[cars.origin == 'japan'].groupby('model_year')['mpg'].mean()

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.bar(mpg_mean_usa.keys(), mpg_mean_usa.values, label='usa', color='blue', alpha=0.7)
plt.bar(mpg_mean_japan.keys(), mpg_mean_japan.values, bottom=mpg_mean_usa.values, label='japan', color='yellow', alpha=0.7)
plt.xlabel('Model year')
plt.ylabel('mean MPG')
plt.title('Evite este gráfico', fontsize=14, weight='bold', color='r')
plt.legend()

plt.subplot(1,2,2)
ind= np.arange(len(mpg_mean_usa.keys()))
barwidth= 0.4

plt.bar(ind + barwidth*0, mpg_mean_usa.values, barwidth, label='usa', color='blue', alpha=0.7)
plt.bar(ind + barwidth*1, mpg_mean_japan.values, barwidth, label='japan', color='yellow', alpha=0.7)

plt.xlabel('Model year')
plt.ylabel('mean MPG')
plt.title('Prefira este gráfico', fontsize=14, weight='bold')
plt.yticks(ind + barwidth / 2, mpg_mean_usa.keys())
plt.legend()

plt.tight_layout()
plt.show()

# %%
cars.mpg.max()
# Out:
# 46.6

# %%
plt.figure(figsize=(8,6))

plt.bar(be['type'], be['2018'], label='BE', color='lightblue')
plt.bar(pt['type'], -pt['2018'], label='PT', color='red') ##invertendo o sinal para barras simétricas

plt.xlabel('Energy type')
plt.ylabel('Energy (giga watts)')
plt.title('Belgium & Portugal - Energy by type (2018)', fontsize=14, weight='bold')
plt.xticks(rotation=60)
plt.yticks([])
plt.legend()

plt.show()

# %% [markdown]
# *Diferença Matplotlib X Seaborn*
#
# Matplotlib bar -> exibe todos os valores
# Seaborn bar -> exibe o valor médio +- IC

# %%
data = pd.DataFrame ({'tipo':
                      pd.Series(['A', 'A', 'A', 'B', 'B', 'B']), 'valor':
                      pd.Series([0,10,20,30,40,50])})

plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.bar(data.tipo, data.valor, color='blue', edgecolor='k', alpha=0.2)

plt.ylim([0,60]);
plt.text(0,92, '   max = ' + str(data[data.tipo == 'B'].valor.max()), fontsize=14)
plt.axhline(y = data[data.tipo == 'B'].valor.max(), color = '#cc0000', linestyle = '--')
plt.title('Matplotlib\n exibe o valor max', fontsize=14, weight='bold')

plt.subplot(1,2,2)
sns.barplot(x=data.tipo, y=data.valor, color='yellow', alpha=0.9)

plt.ylim([0,105])
plt.text(0,72, '   média = ' + str(data[data.tipo == 'B'].valor.mean()), fontsize=14)
plt.axhline(y = data[data.tipo == 'B'].valor.mean(), color='#cc0000', linestyle='--')
plt.title('Seaborn\n exibe o valor média e IC', fontsize=14, weight='bold')

plt.tight_layout()
plt.show()

# %%
cars = sns.load_dataset('mpg')
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
fig= plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.bar(cars.model_year, cars.weight, color='lightblue')

plt.title('Evite este gráfico \nValores Sobrepostos', fontsize=14, weight='bold', color='r')
plt.xlabel('Year model')
plt.ylabel('Weight')

plt.subplot(1,2,2)
g= cars.groupby('model_year').weight.mean()
g_std= cars.groupby('model_year').weight.std()
plt.bar(g.keys(), g.values, yerr=g_std.values, color='yellow', alpha=0.9)

plt.title('Prefira este gráfico \nValores médios', fontsize=14, weight='bold')
plt.xlabel('Year model')
plt.ylabel('Weight')

plt.tight_layout()
plt.show()
